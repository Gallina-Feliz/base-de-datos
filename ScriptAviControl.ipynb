-- %% [markdown]
-- # [dbo].[Alimentacion]

-- %%
USE [AviControl]
GO

-- %%
/****** Object:  Table [dbo].[Alimentacion]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Alimentacion](
	[Id_Alimentacion] [smallint] IDENTITY(1,1) NOT NULL,
	[CantidadAlimento] [smallint] NULL,
	[TipoAlimento] [varchar](100) NULL,
	[Fecha] [datetime] NULL,
	[Numero_Galpon] [smallint] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Alimentacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Gallinas]

-- %%
/****** Object:  Table [dbo].[Gallinas]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Gallinas](
	[Codigo_Gallinas] [smallint] NOT NULL,
	[Fecha_ingreso] [datetime] NULL,
	[Fecha_Nacimiento] [date] NULL,
	[Numero_Galpon] [smallint] NULL,
	[Id_Raza] [tinyint] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Codigo_Gallinas] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Galpones]

-- %%
/****** Object:  Table [dbo].[Galpones]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Galpones](
	[Numero_Galpon] [smallint] NOT NULL,
	[Tipo_Galpon] [varchar](50) NULL,
	[Numero_Gallinas] [smallint] NULL,
PRIMARY KEY CLUSTERED 
(
	[Numero_Galpon] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Huevo]

-- %%
/****** Object:  Table [dbo].[Huevo]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Huevo](
	[Id_Huevo] [tinyint] IDENTITY(1,1) NOT NULL,
	[Fecha] [date] NULL,
	[Cantidad] [smallint] NULL,
	[Numero_Galpon] [smallint] NULL,
	[Id_TipoHuevo] [tinyint] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Huevo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Raza]

-- %%
/****** Object:  Table [dbo].[Raza]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Raza](
	[Id_Raza] [int] IDENTITY(1,1) NOT NULL,
	[Raza] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Raza] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SaludGallinas]

-- %%
/****** Object:  Table [dbo].[SaludGallinas]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SaludGallinas](
	[Id_SaludGallina] [int] IDENTITY(1,1) NOT NULL,
	[Id_Gallina] [smallint] NOT NULL,
	[Fecha] [datetime] NULL,
	[Tipo_Registro] [varchar](100) NULL,
	[Detalle] [text] NULL,
	[Medicamentos] [varchar](100) NULL,
	[Dosis] [varchar](100) NULL,
	[Fecha_vacuna] [datetime] NULL,
	[Fecha_diagnostico] [datetime] NULL,
	[Enfermedad] [varchar](100) NULL,
	[Peso] [int] NULL,
	[Temperatura] [float] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_SaludGallina] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipo_Huevo]

-- %%
/****** Object:  Table [dbo].[Tipo_Huevo]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tipo_Huevo](
	[Id_TipoHuevo] [tinyint] IDENTITY(1,1) NOT NULL,
	[Tipo_Huevo] [varchar](40) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_TipoHuevo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[IdUsuario] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](50) NULL,
	[Email] [varchar](50) NULL,
	[Password] [varchar](100) NULL,
	[FechaCreacion] [datetime] NULL,
	[Activo] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UC_Email] UNIQUE NONCLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__SaludGall__Fecha__76969D2E]

-- %%
ALTER TABLE [dbo].[SaludGallinas] ADD  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF__SaludGall__Fecha__778AC167]

-- %%
ALTER TABLE [dbo].[SaludGallinas] ADD  DEFAULT (getdate()) FOR [Fecha_diagnostico]
GO

-- %% [markdown]
-- # [DF__Usuario__FechaCr__25869641]

-- %%
ALTER TABLE [dbo].[Usuario] ADD  DEFAULT (getdate()) FOR [FechaCreacion]
GO

-- %% [markdown]
-- # [DF__Usuario__Activo__267ABA7A]

-- %%
ALTER TABLE [dbo].[Usuario] ADD  DEFAULT ((1)) FOR [Activo]
GO

-- %% [markdown]
-- # [FK_Alimentacion_Galpones]

-- %%
ALTER TABLE [dbo].[Alimentacion]  WITH CHECK ADD  CONSTRAINT [FK_Alimentacion_Galpones] FOREIGN KEY([Numero_Galpon])
REFERENCES [dbo].[Galpones] ([Numero_Galpon])
GO
ALTER TABLE [dbo].[Alimentacion] CHECK CONSTRAINT [FK_Alimentacion_Galpones]
GO

-- %% [markdown]
-- # [FK_Gallinas_Galpones]

-- %%
ALTER TABLE [dbo].[Gallinas]  WITH CHECK ADD  CONSTRAINT [FK_Gallinas_Galpones] FOREIGN KEY([Numero_Galpon])
REFERENCES [dbo].[Galpones] ([Numero_Galpon])
GO
ALTER TABLE [dbo].[Gallinas] CHECK CONSTRAINT [FK_Gallinas_Galpones]
GO

-- %% [markdown]
-- # [FK_Huevo_Galpones]

-- %%
ALTER TABLE [dbo].[Huevo]  WITH CHECK ADD  CONSTRAINT [FK_Huevo_Galpones] FOREIGN KEY([Numero_Galpon])
REFERENCES [dbo].[Galpones] ([Numero_Galpon])
GO
ALTER TABLE [dbo].[Huevo] CHECK CONSTRAINT [FK_Huevo_Galpones]
GO

-- %% [markdown]
-- # [FK_Huevo_TipoHuevo]

-- %%
ALTER TABLE [dbo].[Huevo]  WITH CHECK ADD  CONSTRAINT [FK_Huevo_TipoHuevo] FOREIGN KEY([Id_TipoHuevo])
REFERENCES [dbo].[Tipo_Huevo] ([Id_TipoHuevo])
GO
ALTER TABLE [dbo].[Huevo] CHECK CONSTRAINT [FK_Huevo_TipoHuevo]
GO

-- %% [markdown]
-- # [FK__SaludGall__Id_Ga__787EE5A0]

-- %%
ALTER TABLE [dbo].[SaludGallinas]  WITH CHECK ADD FOREIGN KEY([Id_Gallina])
REFERENCES [dbo].[Gallinas] ([Codigo_Gallinas])
GO

-- %% [markdown]
-- # [dbo].[ActualizarSaludGallina]

-- %%
/****** Object:  StoredProcedure [dbo].[ActualizarSaludGallina]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ActualizarSaludGallina]
    @Id_SaludGallina int,
    @Tipo_Registro varchar(100),
    @Detalle text,
    @Medicamentos varchar(100),
    @Dosis varchar(100),
    @Fecha_vacuna datetime = NULL,
    @Enfermedad varchar(100) = NULL,
    @Peso int,
    @Temperatura float
AS
BEGIN
    BEGIN TRY
        BEGIN TRANSACTION;
        
        -- Actualización del registro de salud
        UPDATE SaludGallinas
        SET 
            Tipo_Registro = @Tipo_Registro,
            Detalle = @Detalle,
            Medicamentos = @Medicamentos,
            Dosis = @Dosis,
            Fecha_vacuna = @Fecha_vacuna,
            Enfermedad = @Enfermedad,
            Peso = @Peso,
            Temperatura = @Temperatura
        WHERE 
            Id_SaludGallina = @Id_SaludGallina;
        
        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[ConsultarSaludGallina]

-- %%
/****** Object:  StoredProcedure [dbo].[ConsultarSaludGallina]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ConsultarSaludGallina]
    @Id_Gallina smallint
AS
BEGIN
    -- Consulta del historial de salud de la gallina
    SELECT 
        Id_SaludGallina,
        Id_Gallina,
        Fecha,
        Tipo_Registro,
        Detalle,
        Medicamentos,
        Dosis,
        Fecha_vacuna,
        Fecha_diagnostico,
        Enfermedad,
        Peso,
        Temperatura
    FROM 
        SaludGallinas
    WHERE 
        Id_Gallina = @Id_Gallina;
END;
GO

-- %% [markdown]
-- # [dbo].[DeleteGalpon]

-- %%
/****** Object:  StoredProcedure [dbo].[DeleteGalpon]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[DeleteGalpon]
    @Numero_Galpon smallint,
    @Nuevo_Numero_Galpon smallint -- Nuevo galpón al que se trasladarán las gallinas
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        -- Verificar si el nuevo galpón existe
        IF NOT EXISTS (SELECT 1 FROM Galpones WHERE Numero_Galpon = @Nuevo_Numero_Galpon)
        BEGIN
            THROW 50000, 'El nuevo galpón especificado no existe.', 1;
        END

        -- Verificar si hay gallinas registradas en el galpón que se desea eliminar
        IF EXISTS (SELECT 1 FROM Gallinas WHERE Numero_Galpon = @Numero_Galpon)
        BEGIN
            -- Contar el número de gallinas en el galpón a eliminar
            DECLARE @CantidadGallinas int;
            SELECT @CantidadGallinas = COUNT(*) FROM Gallinas WHERE Numero_Galpon = @Numero_Galpon;

            -- Actualizar el número de gallinas en el nuevo galpón
            UPDATE Galpones
            SET Numero_Gallinas = Numero_Gallinas + @CantidadGallinas
            WHERE Numero_Galpon = @Nuevo_Numero_Galpon;

            -- Actualizar el número de gallinas en el galpón a eliminar
            UPDATE Galpones
            SET Numero_Gallinas = 0
            WHERE Numero_Galpon = @Numero_Galpon;

            -- Actualizar el galpón de las gallinas registradas
            UPDATE Gallinas
            SET Numero_Galpon = @Nuevo_Numero_Galpon
            WHERE Numero_Galpon = @Numero_Galpon;
        END

        -- Eliminar el galpón
        DELETE FROM Galpones WHERE Numero_Galpon = @Numero_Galpon;

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[DeleteHuevo]

-- %%
/****** Object:  StoredProcedure [dbo].[DeleteHuevo]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[DeleteHuevo]
    @Id_Huevo tinyint
AS
BEGIN
    DELETE FROM Huevo WHERE Id_Huevo = @Id_Huevo;
END;
GO

-- %% [markdown]
-- # [dbo].[DeleteRaza]

-- %%
/****** Object:  StoredProcedure [dbo].[DeleteRaza]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[DeleteRaza]
    @Id_Raza smallint
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        -- Verificar si hay gallinas asociadas a esta raza
        IF EXISTS (SELECT 1 FROM Gallinas WHERE Id_Raza = @Id_Raza)
        BEGIN
            THROW 50000, 'No se puede eliminar la raza porque hay gallinas asociadas a esta raza.', 1;
        END

        -- Eliminar la raza
        DELETE FROM Raza
        WHERE Id_Raza = @Id_Raza;

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[EliminarGallina]

-- %%
/****** Object:  StoredProcedure [dbo].[EliminarGallina]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[EliminarGallina]
    @Codigo_Gallinas smallint
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        -- Obtener el galpón actual de la gallina
        DECLARE @Numero_Galpon smallint;
        SELECT @Numero_Galpon = Numero_Galpon FROM Gallinas WHERE Codigo_Gallinas = @Codigo_Gallinas;

        -- Eliminar la gallina
        DELETE FROM Gallinas WHERE Codigo_Gallinas = @Codigo_Gallinas;

        -- Actualizar el número de gallinas en el galpón
        UPDATE Galpones
        SET Numero_Gallinas = Numero_Gallinas - 1
        WHERE Numero_Galpon = @Numero_Galpon;

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[EliminarSaludGallina]

-- %%
/****** Object:  StoredProcedure [dbo].[EliminarSaludGallina]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[EliminarSaludGallina]
    @Id_SaludGallina int
AS
BEGIN
    BEGIN TRY
        BEGIN TRANSACTION;
        
        -- Eliminación del registro de salud
        DELETE FROM SaludGallinas
        WHERE Id_SaludGallina = @Id_SaludGallina;
        
        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[InsertAlimentacion]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertAlimentacion]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertAlimentacion]
    @CantidadAlimento SMALLINT,
    @TipoAlimento VARCHAR(100),
    @Fecha DATETIME,
    @Numero_Galpon SMALLINT
AS
BEGIN
    -- Verificar que el galpón existe
    IF NOT EXISTS (SELECT 1 FROM Galpones WHERE Numero_Galpon = @Numero_Galpon)
    BEGIN
        THROW 50000, 'El galpón especificado no existe.', 1;
    END

    -- Insertar la alimentación
    INSERT INTO Alimentacion (CantidadAlimento, TipoAlimento, Fecha, Numero_Galpon)
    VALUES (@CantidadAlimento, @TipoAlimento, @Fecha, @Numero_Galpon);
END;
GO

-- %% [markdown]
-- # [dbo].[InsertGallinaYActualizarGalpon]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertGallinaYActualizarGalpon]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertGallinaYActualizarGalpon]
    @Codigo_Gallinas smallint,
    @Id_Raza smallint,  -- Usar Id_Raza en lugar de nombre de raza
    @Fecha_Nacimiento date,
    @Numero_Galpon smallint
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        -- Inserción de la gallina
        INSERT INTO Gallinas (Codigo_Gallinas, Id_Raza, Fecha_ingreso, Fecha_Nacimiento, Numero_Galpon)
        VALUES (@Codigo_Gallinas, @Id_Raza, GETDATE(), @Fecha_Nacimiento, @Numero_Galpon);

        -- Actualización del número de gallinas en el galpón
        UPDATE Galpones
        SET Numero_Gallinas = Numero_Gallinas + 1
        WHERE Numero_Galpon = @Numero_Galpon;

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[InsertGalpon]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertGalpon]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertGalpon]
    @Numero_Galpon smallint,
    @Tipo_Galpon varchar(50)
AS
BEGIN
    INSERT INTO Galpones (Numero_Galpon, Tipo_Galpon, Numero_Gallinas)
    VALUES (@Numero_Galpon, @Tipo_Galpon, 0);
END;
GO

-- %% [markdown]
-- # [dbo].[InsertHuevo]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertHuevo]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertHuevo]
    @Cantidad smallint,
    @Id_TipoHuevo tinyint,
    @Numero_Galpon smallint
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        -- Verificar que el galpón existe
        IF NOT EXISTS (SELECT 1 FROM Galpones WHERE Numero_Galpon = @Numero_Galpon)
        BEGIN
            THROW 50000, 'El galpón especificado no existe.', 1;
        END

        -- Verificar que el tipo de huevo existe
        IF NOT EXISTS (SELECT 1 FROM Tipo_Huevo WHERE Id_TipoHuevo = @Id_TipoHuevo)
        BEGIN
            THROW 50000, 'El tipo de huevo especificado no existe.', 1;
        END

        -- Insertar el huevo con la fecha actual
        INSERT INTO Huevo (Cantidad, Fecha, Id_TipoHuevo, Numero_Galpon)
        VALUES (@Cantidad, GETDATE(), @Id_TipoHuevo, @Numero_Galpon);

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[InsertRaza]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertRaza]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertRaza]
    @Raza varchar(100)
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        INSERT INTO Raza (Raza)
        VALUES (@Raza);

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[InsertSaludGallina]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertSaludGallina]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertSaludGallina]

    @Id_Gallina smallint,
    @Tipo_Registro varchar(100),
    @Detalle text,
    @Medicamentos varchar(100),
    @Dosis varchar(100),
    @Fecha_vacuna datetime = NULL,
    @Enfermedad varchar(100) = NULL,
    @Peso int,
    @Temperatura float
AS
BEGIN
    BEGIN TRY
        BEGIN TRANSACTION;
        
        -- Verificar si el Id_Gallina existe en la tabla Gallinas
        IF NOT EXISTS (SELECT 1 FROM Gallinas WHERE Codigo_Gallinas = @Id_Gallina)
        BEGIN
            THROW 50000, 'El Id de la gallina no existe.', 1;
        END
        
        -- Inserción de los datos con fechas automáticas
        INSERT INTO SaludGallinas (
            Id_Gallina, Tipo_Registro, Detalle, Medicamentos, Dosis, 
            Fecha_vacuna, Enfermedad, Peso, Temperatura
        )
        VALUES (
            @Id_Gallina, @Tipo_Registro, @Detalle, @Medicamentos, @Dosis,
            @Fecha_vacuna, @Enfermedad, @Peso, @Temperatura
        );
        
        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;

GO

-- %% [markdown]
-- # [dbo].[InsertTipoHuevo]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertTipoHuevo]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertTipoHuevo]
    @Tipo_Huevo varchar(40)
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        INSERT INTO Tipo_Huevo (Tipo_Huevo)
        VALUES (@Tipo_Huevo);

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;

GO

-- %% [markdown]
-- # [dbo].[ListarAlimentacion]

-- %%
/****** Object:  StoredProcedure [dbo].[ListarAlimentacion]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ListarAlimentacion]
AS
BEGIN
    SELECT 
        A.Id_Alimentacion,
        A.CantidadAlimento,
        A.TipoAlimento,
        A.Fecha,
        G.Numero_Galpon,
        G.Tipo_Galpon
    FROM 
        Alimentacion A
    JOIN 
        Galpones G ON A.Numero_Galpon = G.Numero_Galpon;
END;
GO

-- %% [markdown]
-- # [dbo].[ListarGallinas]

-- %%
/****** Object:  StoredProcedure [dbo].[ListarGallinas]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ListarGallinas]
AS
BEGIN
    SELECT 
        G.Codigo_Gallinas,
        G.Fecha_ingreso,
        G.Fecha_Nacimiento,
        R.Raza,
		g.Numero_Galpon
    FROM Gallinas G
    JOIN Raza R ON G.Id_Raza = R.Id_Raza;
END;
GO

-- %% [markdown]
-- # [dbo].[ListarGalpones]

-- %%
/****** Object:  StoredProcedure [dbo].[ListarGalpones]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ListarGalpones]
AS
BEGIN
    -- Seleccionar información básica de los galpones
    SELECT 
        g.Numero_Galpon,
        g.Tipo_Galpon,
        g.Numero_Gallinas,
        -- Información de alimentación (si existe)
        ISNULL(a.CantidadAlimento, 0) AS CantidadAlimento,
        ISNULL(a.TipoAlimento, 'N/A') AS TipoAlimento,
        ISNULL(a.Fecha, '1900-01-01') AS FechaAlimentacion,
        -- Información de huevos (si existe)
        ISNULL(SUM(h.Cantidad), 0) AS CantidadHuevos,
        ISNULL(MAX(h.Fecha), '1900-01-01') AS FechaHuevos,
        ISNULL(t.Tipo_Huevo, 'N/A') AS TipoHuevo
    FROM 
        Galpones g
    LEFT JOIN 
        Alimentacion a ON g.Numero_Galpon = a.Numero_Galpon
    LEFT JOIN 
        Huevo h ON g.Numero_Galpon = h.Numero_Galpon
    LEFT JOIN 
        Tipo_Huevo t ON h.Id_TipoHuevo = t.Id_TipoHuevo
    GROUP BY 
        g.Numero_Galpon, 
        g.Tipo_Galpon, 
        g.Numero_Gallinas,
        a.CantidadAlimento,
        a.TipoAlimento,
        a.Fecha,
        t.Tipo_Huevo;
END;
GO

-- %% [markdown]
-- # [dbo].[ListarHuevo]

-- %%
/****** Object:  StoredProcedure [dbo].[ListarHuevo]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[ListarHuevo]
AS
BEGIN
    SELECT H.Cantidad, H.Fecha, TH.Tipo_Huevo, G.Numero_Galpon, G.Tipo_Galpon
    FROM Huevo H
    JOIN Tipo_Huevo TH ON H.Id_TipoHuevo = TH.Id_TipoHuevo
    JOIN Galpones G ON H.Numero_Galpon = G.Numero_Galpon;
END;
GO

-- %% [markdown]
-- # [dbo].[ListarRaza]

-- %%
/****** Object:  StoredProcedure [dbo].[ListarRaza]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ListarRaza]
AS
BEGIN
    SELECT * FROM Raza;
END;
GO

-- %% [markdown]
-- # [dbo].[ListarRazas]

-- %%
/****** Object:  StoredProcedure [dbo].[ListarRazas]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ListarRazas]
AS
BEGIN
    SELECT Id_Raza, Raza FROM Raza ORDER BY Raza;
END;

GO

-- %% [markdown]
-- # [dbo].[ListarSaludGallinas]

-- %%
/****** Object:  StoredProcedure [dbo].[ListarSaludGallinas]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ListarSaludGallinas]
AS
BEGIN
    SELECT 
        s.Id_SaludGallina,
        s.Id_Gallina,
        s.Fecha,
        s.Tipo_Registro,
        s.Detalle,
        s.Medicamentos,
        s.Dosis,
        s.Fecha_vacuna,
        s.Fecha_diagnostico,
        s.Enfermedad,
        s.Peso,
        s.Temperatura
    FROM 
        SaludGallinas s
    ORDER BY 
        s.Fecha DESC;
END;
GO

-- %% [markdown]
-- # [dbo].[ListarTipoHuevoConConteo]

-- %%
/****** Object:  StoredProcedure [dbo].[ListarTipoHuevoConConteo]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[ListarTipoHuevoConConteo]
AS
BEGIN
    SELECT 
        TH.Id_TipoHuevo,
        TH.Tipo_Huevo,
        ISNULL(SUM(H.Cantidad), 0) AS Cantidad_Total_Huevos
    FROM Tipo_Huevo TH
    LEFT JOIN Huevo H ON TH.Id_TipoHuevo = H.Id_TipoHuevo
    GROUP BY TH.Id_TipoHuevo, TH.Tipo_Huevo;
END;
GO

-- %% [markdown]
-- # [dbo].[UpdateAlimentacion]

-- %%
/****** Object:  StoredProcedure [dbo].[UpdateAlimentacion]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[UpdateAlimentacion]
    @Id_Alimentacion smallint,
    @CantidadAlimento smallint,
    @TipoAlimento varchar(100),
    @Fecha datetime,
    @Numero_Galpon smallint
AS
BEGIN
    -- Verificar que la alimentación existe
    IF NOT EXISTS (SELECT 1 FROM Alimentacion WHERE Id_Alimentacion = @Id_Alimentacion)
    BEGIN
        THROW 50000, 'El registro de alimentación especificado no existe.', 1;
    END

    -- Verificar que el galpón existe
    IF NOT EXISTS (SELECT 1 FROM Galpones WHERE Numero_Galpon = @Numero_Galpon)
    BEGIN
        THROW 50000, 'El galpón especificado no existe.', 1;
    END

    -- Actualizar la alimentación
    UPDATE Alimentacion
    SET 
        CantidadAlimento = @CantidadAlimento,
        TipoAlimento = @TipoAlimento,
        Fecha = @Fecha,
        Numero_Galpon = @Numero_Galpon
    WHERE 
        Id_Alimentacion = @Id_Alimentacion;
END;
GO

-- %% [markdown]
-- # [dbo].[UpdateGallina]

-- %%
/****** Object:  StoredProcedure [dbo].[UpdateGallina]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[UpdateGallina]
    @Codigo_Gallinas smallint,
    @Id_Raza smallint,
    @Fecha_Nacimiento date,
    @Nuevo_Numero_Galpon smallint
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        -- Obtener el galpón actual de la gallina
        DECLARE @Galpon_Anterior smallint;
        SELECT @Galpon_Anterior = Numero_Galpon 
        FROM Gallinas 
        WHERE Codigo_Gallinas = @Codigo_Gallinas;

        -- Verificar si se obtuvo el galpón anterior
        IF @Galpon_Anterior IS NULL
        BEGIN
            THROW 50001, 'La gallina con el código proporcionado no existe.', 1;
        END

        -- Actualizar la raza y el galpón de la gallina
        UPDATE Gallinas
        SET 
            Id_Raza = @Id_Raza,
            Fecha_Nacimiento = @Fecha_Nacimiento,
            Numero_Galpon = @Nuevo_Numero_Galpon
        WHERE 
            Codigo_Gallinas = @Codigo_Gallinas;

        -- Actualizar el número de gallinas en el galpón anterior si es diferente al nuevo
        IF @Galpon_Anterior <> @Nuevo_Numero_Galpon
        BEGIN
            UPDATE Galpones
            SET Numero_Gallinas = Numero_Gallinas - 1
            WHERE Numero_Galpon = @Galpon_Anterior;

            UPDATE Galpones
            SET Numero_Gallinas = Numero_Gallinas + 1
            WHERE Numero_Galpon = @Nuevo_Numero_Galpon;
        END

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[UpdateGalpon]

-- %%
/****** Object:  StoredProcedure [dbo].[UpdateGalpon]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[UpdateGalpon]
    @Numero_Galpon smallint,
    @Tipo_Galpon varchar(50)
AS
BEGIN
    UPDATE Galpones
    SET Tipo_Galpon = @Tipo_Galpon
    WHERE Numero_Galpon = @Numero_Galpon;
END;
GO

-- %% [markdown]
-- # [dbo].[UpdateHuevo]

-- %%
/****** Object:  StoredProcedure [dbo].[UpdateHuevo]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[UpdateHuevo]
    @Id_Huevo tinyint,
    @Cantidad smallint,
    @Id_TipoHuevo tinyint,
    @Numero_Galpon smallint
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        -- Verificar que el galpón existe
        IF NOT EXISTS (SELECT 1 FROM Galpones WHERE Numero_Galpon = @Numero_Galpon)
        BEGIN
            THROW 50000, 'El galpón especificado no existe.', 1;
        END

        -- Verificar que el tipo de huevo existe
        IF NOT EXISTS (SELECT 1 FROM Tipo_Huevo WHERE Id_TipoHuevo = @Id_TipoHuevo)
        BEGIN
            THROW 50000, 'El tipo de huevo especificado no existe.', 1;
        END

        -- Actualizar el registro de huevo
        UPDATE Huevo
        SET Cantidad = @Cantidad,
            Id_TipoHuevo = @Id_TipoHuevo,
            Numero_Galpon = @Numero_Galpon
        WHERE Id_Huevo = @Id_Huevo;

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[UpdateRaza]

-- %%
/****** Object:  StoredProcedure [dbo].[UpdateRaza]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[UpdateRaza]
    @Id_Raza smallint,
    @Raza varchar(100)
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        UPDATE Raza
        SET Raza = @Raza
        WHERE Id_Raza = @Id_Raza;

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[UpdateTipoHuevo]

-- %%
/****** Object:  StoredProcedure [dbo].[UpdateTipoHuevo]    Script Date: 5/09/2024 7:31:37 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[UpdateTipoHuevo]
    @Id_TipoHuevo tinyint,
    @Tipo_Huevo varchar(40)
AS
BEGIN
    BEGIN TRANSACTION;
    BEGIN TRY
        UPDATE Tipo_Huevo
        SET Tipo_Huevo = @Tipo_Huevo
        WHERE Id_TipoHuevo = @Id_TipoHuevo;

        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        ROLLBACK TRANSACTION;
        -- Manejo de errores
        THROW;
    END CATCH;
END;
GO
